# %%
#!/bin/python3
import math
import os
import random
import re
import sys

# %%
employees_ids = list(map(chr, range(97, 123)))

def findLongestSingleSlot(leaveTimes):
    # The function is expected to return a CHARACTER.
    # The function accepts 2D_INTEGER_ARRAY leaveTimes as parameter.
    # Find the ID of the employe who has 
    # the longest single time slot at the task
    previous_time = 0
    employee_longest_work_time = 0
    employee_id_longest_work_time = None
    for leaveTime in leaveTimes:
        employee_leave_time = leaveTime[1]
        longest_work_time = employee_leave_time - previous_time
        previous_time = employee_leave_time
        if longest_work_time > employee_longest_work_time:
            employee_longest_work_time = longest_work_time
            employee_id_longest_work_time = leaveTime[0]
        
    return employees_ids[employee_id_longest_work_time]
leaveTimes = [[0, 2], [1, 3], [0, 7]]
result = findLongestSingleSlot(leaveTimes)
print(result)
# Out:
# a

# %%
#
# Complete the 'getFinalOrder' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER k
#  2. INTEGER_ARRAY amount
#

def getFinalOrder(k, amount):
    final_order = list()
    Q = [i for i in range(1, len(amount)+1)]
    #print(Q)
    while Q:
        q = Q[0]
        total_current = amount[q-1]
        #print(f"Persona {q}, requiere: ${total_current}")
        #print(f"{total_current} <= {k}")
        if total_current <= k:
            amount[q-1] = 0
            final_order.append(q)
            Q.pop(0)
            #print(f"Sale de fila la persona: {q}")
        else:
            amount[q-1] = total_current - k
            Q.pop(0)
            Q.append(q)
            #print(f"Se mueve a la cola la persona: {q}, le queda por sacar ${amount[q-1]}")
        #print("Fila actual", Q)
        #print("amount", amount)
        if Q is None:
            break
    return final_order

k = 2
amount = [1, 3, 2]
print(getFinalOrder(k, amount))
# Out:
# [1, 3, 2]

# %% [markdown]
# Given an array of integers, amount[n], each amount[i] represents the amount of money required by person i. There are n people numbered 1 through n standing in an ATM queue in increasing order. A person can withdraw at most k units of currency at one time.
#
# Return an array of people number in the order that they leave the queue, i.e. the order their needed amounts have been withdrawn.
#
# Call the cumulative amount of money withdrawn current, and the money required total.
#
# Repeat the following process until the queue is empty:
# 1. If total - current <= k
#    1. withdraw (total - current)
#    2. leave the queue
#    3. store the person's i in the return array
# 2. Otherwise
#    1. withdraw k
#    2. current = current + k
#    3. move to the back of the queue
#
# [0,1,1,1,2]
#
# [2, 5, 1]
# [0, 1, 2, 1, 1]

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



#
# Complete the 'getFinalOrder' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER k
#  2. INTEGER_ARRAY amount
#



def getFinalOrder(k, amount):
    print(k)
    print(amount)
    final_order = list()
    Q = [i for i in range(1, len(amount)+1)]
    while Q:
        q = Q[0]
        total_current = amount[q-1]
        if total_current <= k:
            amount[q-1] = 0
            final_order.append(q)
            Q.pop(0)
        else:
            amount[q-1] = total_current - k
            Q.pop(0)
            Q.append(q)
        if Q is None:
            break
    return final_order
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    k = int(input().strip())

    amount_count = int(input().strip())

    amount = []

    for _ in range(amount_count):
        amount_item = int(input().strip())
        amount.append(amount_item)

    result = getFinalOrder(k, amount)

    fptr.write('\n'.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
k = 940
#amount = [55614216, 27811267, 682119749, 31529143, 463871382, 68045065, 194590518, 615499844, 702561521, 122012839, 515244530, 384402575, 38787856, 468658949, 524069511, 293945127, 117973516, 175300513, 380043430, 979010606, 430891582, 785924327, 815821339, 362082743, 36951931, 683618208, 863487806, 460133247, 633050728, 582137119, 108742100, 221188446, 622873100, 3089823, 81295763, 991505134, 608025731, 257443639, 114932942, 778755329, 842820245, 953587348, 422116040, 397221438, 648227463, 730997781, 983124654, 851640688, 584870273, 309574605, 838764950, 811
, 454102305, 659232561, 402288936, 680746793, 636728463, 285386898, 886090951, 790030022, 285910814, 319638451, 553487594, 989880948, 264448005, 113279422, 322365823, 621878272, 377760260, 60537064, 327371882, 911185572, 12458382, 721240548, 788067192, 196512811, 381480583, 602581346, 201625422, 185072518, 442990491, 875084918, 637103540, 897532123, 245182294, 337240316, 186953871, 137800946, 985722847, 408740777, 41702075, 680613834, 725012944, 755374317, 56850662, 243933369, 459427855, 295311800, 335216515, 60988037, 893563370, 845460673, 132514542, 757929039, 985834624, 155796159, 910468298, 85401721, 565016556, 388519142, 770010319, 201130021, 117793523, 202880149, 437583645, 591837650, 524839255, 410598155, 430814830, 270445147, 131763657, 989153145, 960160161, 79227716, 59534120, 98173154, 963887658, 695203956, 845546569, 231544758, 788168748, 718771040, 290329370, 674884321, 912253392, 500510830, 15674397, 739848888, 68092937, 334570751, 205122955, 584157638, 778172872, 921913015, 907903653, 483094469, 476992600, 539728157, 172429909, 494794255, 61044675, 718563399, 998718125, 119608545, 201130411, 614436657, 882927681, 314616388, 853513763, 303444918, 256538999, 247803254, 764246010, 424990141, 460565149, 872011887, 982873034, 169889718, 360040125, 611797454, 907380938, 518695740, 359335914, 597203995, 946103479, 975707695, 634653362, 82073864, 82289575, 711698770, 430717304, 445849191, 815506068, 621738551, 564519229, 260731152, 824047394, 39453891, 121004210, 992979719, 968823076, 619423521, 224045514, 428359530, 268929950, 791573211, 165043565, 319348344, 123287868, 769991154, 759512065, 872846911, 799843277, 973858173, 544207120, 860414952, 162038750, 276817116, 622911710, 929524165, 964190378, 433867289, 743259201, 955262924, 621209285, 458753729, 600807482, 459213035, 995365364, 180836399, 233840006, 708769550, 954097854, 327863323, 424148632, 768781223, 298730831, 178868411, 482869813, 669256399, 796344184, 349036701, 981680927, 125056019, 578784170, 274583170, 822573624, 761824601, 53352650, 880971479, 887437096, 849675381, 917749774, 273433729, 792178463, 366381309, 302593577, 179789360, 311300148, 941268050, 384724552, 487072567, 9734155, 89551409, 957417184, 80114344, 445460453, 858129794, 321816734, 301760628, 608349762, 218008516, 178393390, 526284541, 453340370, 104655014, 723003993, 116787938, 303360241, 403268784, 404899904, 801555017, 289689307, 487090]
#%timeit print(getFinalOrder(k, amount))

# %% [markdown]
# A monkey is jumping on a long staircase, on which each stair is numbered; the bottommost tair being 1, the next stair being 2, and so on. In one jump, it can go some steps up or down.
# Given an array jumps of integers representing each jump of the monked as:
# If jumps[i]> 0, the monkey jumps jumps[i] steps up from its current step.
# If jumps[i]> 0, the monkey jumps jumps[i] steps down from its current step.
# Find the number of the lowest stais, startingStair on which the monkey should start so that it can remain on the staircase; that is, the stair number remains >= 1

# %%
def findLowestStartingStair(jumps):
    print(jumps)
    current_stair = abs(jumps[0])
    count = 0
    print(f"El mono inicia en {current_stair}")
    i = 0
    while True:
        current_stair = current_stair + jumps[i]
        print("Conteo = ",count, "startingStair", current_stair, "jumps[i]", jumps[i])
        if count <= 0:
            i = 0
            current_stair += 1
            print(f"El mono inicia en {current_stair}")
            continue
        i += 1
        print("i = ", i)
        if i >= len(jumps):
            break
    return startingStair
jumps = [-5, 4, -2, 3, 1, -1, -6, -1, 0, 5] # espera un 8
#jumps = [-5, 4, -2, 3, 1] # espera un 7
print(f"Result {findLowestStartingStair(jumps)}")
